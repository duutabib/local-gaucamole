# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
data0 = pd.read_csv('/Users/duuta/drNanaAma/jan2019_aug2019.csv', header='infer', index_col='Date')
# 56 lines of date index

# %% [markdown]
# # convert data Date col to pandas datetime object.

# %%
data00 = data0[:56]

# %%
data00.index = pd.to_datetime(data00.index)

# %%
data00.interpolate(method='spline', order=3, limit_direction='forward', axis=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 data00.interpolate(method='spline', order=3, limit_direction='forward', axis=0)
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/pandas/core/generic.py:8206, in NDFrame.interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    8204 else:
#    8205     index = missing.get_interp_index(method, obj.index)
# -> 8206     new_data = obj._mgr.interpolate(
#    8207         method=method,
#    8208         index=index,
#    8209         limit=limit,
#    8210         limit_direction=limit_direction,
#    8211         limit_area=limit_area,
#    8212         inplace=inplace,
#    8213         downcast=downcast,
#    8214         **kwargs,
#    8215     )
#    8217 result = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    8218 if should_transpose:
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/pandas/core/internals/base.py:265, in DataManager.interpolate(self, inplace, **kwargs)
#     264 def interpolate(self, inplace: bool, **kwargs) -> Self:
# --> 265     return self.apply_with_block(
#     266         "interpolate", inplace=inplace, **kwargs, using_cow=using_copy_on_write()
#     267     )
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/pandas/core/internals/managers.py:354, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     352         applied = b.apply(f, **kwargs)
#     353     else:
# --> 354         applied = getattr(b, f)(**kwargs)
#     355     result_blocks = extend_blocks(applied, result_blocks)
#     357 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/pandas/core/internals/blocks.py:1507, in Block.interpolate(self, method, index, inplace, limit, limit_direction, limit_area, downcast, using_cow, **kwargs)
#    1504 copy, refs = self._get_refs_and_copy(using_cow, inplace)
#    1506 # Dispatch to the EA method.
# -> 1507 new_values = self.array_values.interpolate(
#    1508     method=method,
#    1509     axis=self.ndim - 1,
#    1510     index=index,
#    1511     limit=limit,
#    1512     limit_direction=limit_direction,
#    1513     limit_area=limit_area,
#    1514     copy=copy,
#    1515     **kwargs,
#    1516 )
#    1517 data = extract_array(new_values, extract_numpy=True)
#    1519 nb = self.make_block_same_class(data, refs=refs)
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/pandas/core/arrays/numpy_.py:297, in NumpyExtensionArray.interpolate(self, method, axis, index, limit, limit_direction, limit_area, copy, **kwargs)
#     294     out_data = self._ndarray.copy()
#     296 # TODO: assert we have floating dtype?
# --> 297 missing.interpolate_2d_inplace(
#     298     out_data,
#     299     method=method,
#     300     axis=axis,
#     301     index=index,
#     302     limit=limit,
#     303     limit_direction=limit_direction,
#     304     limit_area=limit_area,
#     305     **kwargs,
#     306 )
#     307 if not copy:
#     308     return self
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/pandas/core/missing.py:370, in interpolate_2d_inplace(data, index, axis, method, limit, limit_direction, limit_area, fill_value, **kwargs)
#     352     _interpolate_1d(
#     353         indices=indices,
#     354         yvalues=yvalues,
#    (...)
#     361         **kwargs,
#     362     )
#     364 # error: Argument 1 to "apply_along_axis" has incompatible type
#     365 # "Callable[[ndarray[Any, Any]], None]"; expected "Callable[...,
#     366 # Union[_SupportsArray[dtype[<nothing>]], Sequence[_SupportsArray
#     367 # [dtype[<nothing>]]], Sequence[Sequence[_SupportsArray[dtype[<nothing>]]]],
#     368 # Sequence[Sequence[Sequence[_SupportsArray[dtype[<nothing>]]]]],
#     369 # Sequence[Sequence[Sequence[Sequence[_SupportsArray[dtype[<nothing>]]]]]]]]"
# --> 370 np.apply_along_axis(func, axis, data)
#
# File <__array_function__ internals>:200, in apply_along_axis(*args, **kwargs)
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/numpy/lib/shape_base.py:379, in apply_along_axis(func1d, axis, arr, *args, **kwargs)
#     375 except StopIteration as e:
#     376     raise ValueError(
#     377         'Cannot apply_along_axis when any iteration dimensions are 0'
#     378     ) from None
# --> 379 res = asanyarray(func1d(inarr_view[ind0], *args, **kwargs))
#     381 # build a buffer for storing evaluations of func1d.
#     382 # remove the requested axis, and add the new ones on the end.
#     383 # laid out so that each write is contiguous.
#     384 # for a tuple index inds, buff[inds] = func1d(inarr_view[inds])
#     385 buff = zeros(inarr_view.shape[:-1] + res.shape, res.dtype)
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/pandas/core/missing.py:352, in interpolate_2d_inplace.<locals>.func(yvalues)
#     349 def func(yvalues: np.ndarray) -> None:
#     350     # process 1-d slices in the axis direction
# --> 352     _interpolate_1d(
#     353         indices=indices,
#     354         yvalues=yvalues,
#     355         method=method,
#     356         limit=limit,
#     357         limit_direction=limit_direction,
#     358         limit_area=limit_area_validated,
#     359         fill_value=fill_value,
#     360         bounds_error=False,
#     361         **kwargs,
#     362     )
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/pandas/core/missing.py:485, in _interpolate_1d(indices, yvalues, method, limit, limit_direction, limit_area, fill_value, bounds_error, order, **kwargs)
#     481     yvalues[invalid] = np.interp(
#     482         indices[invalid], indices[valid][indexer], yvalues[valid][indexer]
#     483     )
#     484 else:
# --> 485     yvalues[invalid] = _interpolate_scipy_wrapper(
#     486         indices[valid],
#     487         yvalues[valid],
#     488         indices[invalid],
#     489         method=method,
#     490         fill_value=fill_value,
#     491         bounds_error=bounds_error,
#     492         order=order,
#     493         **kwargs,
#     494     )
#     496 if is_datetimelike:
#     497     yvalues[preserve_nans] = NaT.value
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/pandas/core/missing.py:558, in _interpolate_scipy_wrapper(x, y, new_x, method, fill_value, bounds_error, order, **kwargs)
#     554     if isna(order) or (order <= 0):
#     555         raise ValueError(
#     556             f"order needs to be specified and greater than 0; got order: {order}"
#     557         )
# --> 558     terp = interpolate.UnivariateSpline(x, y, k=order, **kwargs)
#     559     new_y = terp(new_x)
#     560 else:
#     561     # GH 7295: need to be able to write for some reason
#     562     # in some circumstances: check all three
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/scipy/interpolate/_fitpack2.py:232, in UnivariateSpline.__init__(self, x, y, w, bbox, k, s, ext, check_finite)
#     229 def __init__(self, x, y, w=None, bbox=[None]*2, k=3, s=None,
#     230              ext=0, check_finite=False):
# --> 232     x, y, w, bbox, self.ext = self.validate_input(x, y, w, bbox, k, s, ext,
#     233                                                   check_finite)
#     235     # _data == x,y,w,xb,xe,k,s,n,t,c,fp,fpint,nrdata,ier
#     236     data = dfitpack.fpcurf0(x, y, k, w=w, xb=bbox[0],
#     237                             xe=bbox[1], s=s)
#
# File ~/.pyenv/versions/3.9.16/lib/python3.9/site-packages/scipy/interpolate/_fitpack2.py:257, in UnivariateSpline.validate_input(x, y, w, bbox, k, s, ext, check_finite)
#     255 if s is None or s > 0:
#     256     if not np.all(diff(x) >= 0.0):
# --> 257         raise ValueError("x must be increasing if s > 0")
#     258 else:
#     259     if not np.all(diff(x) > 0.0):
#
# ValueError: x must be increasing if s > 0

# %%
 data00
# Out:
#             Tech_maize  Tech_mill  Tech_imprice  Tech_locrice  Tech_sorg  \
# Date
# 2023-08-01       0.790      1.145         2.505         1.705      1.024
# 2023-07-01       0.813      1.179         2.579         1.755      1.054
# 2023-06-01       0.842      1.247         2.734         1.807      0.994
# 2023-05-01       0.892      1.276         2.817         1.840      1.109
# 2023-04-01       0.897      1.320         2.943         1.893      1.034
# 2023-03-01       0.893      1.303         2.807         1.799      1.229
# 2023-02-01       0.841      1.373         2.927         1.821      1.117
# 2023-01-01       0.776      1.459         3.052         1.945      1.226
# 2022-12-01       0.764      1.614         3.165         1.850      1.259
# 2022-11-01       0.602      1.590         3.334         1.915      1.151
# 2022-10-01       0.537      1.431         2.851         1.779      0.976
# 2022-09-01       0.443      1.422         2.375         1.474      0.908
# 2022-08-01       0.676      1.297         2.374         1.287      0.848
# 2022-07-01       0.725      1.242         2.357         1.228      0.871
# 2022-06-01       0.731      1.216         2.381         1.243      0.900
# 2022-05-01       0.787      1.248         2.441         1.171      0.926
# 2022-04-01       0.765      1.421         2.286         1.149      0.934
# 2022-03-01       0.776      1.284         2.386         1.208      0.778
# 2022-02-01       0.595      0.869         2.471         1.229      0.733
# 2022-01-01       0.597      0.991         2.350         1.194      0.735
# 2021-12-01       0.632      0.966         2.264         1.225      0.778
# 2021-11-01       0.679      0.912         2.295         1.250      0.801
# 2021-10-01       0.690      0.924         2.373         1.156      0.745
# 2021-09-01       0.872      0.923         2.351         1.260      0.717
# 2021-08-01       0.864      0.937         2.445         1.268      0.733
# 2021-07-01       0.769      0.929         2.411         1.266      0.736
# 2021-06-01       0.735      0.955         2.439         1.273      0.640
# 2021-05-01         NaN        NaN           NaN           NaN        NaN
# 2021-04-01       0.595      1.035         2.474         1.279      0.669
# 2021-03-01       0.539      0.989         2.505         1.257      0.701
# 2021-02-01       0.492      0.873         2.550         1.330      0.669
# 2021-01-01       0.543      1.004         2.580         1.360      0.655
# 2020-12-01       0.544      0.966         2.664         1.423      0.707
# 2020-11-01       0.383      1.053         2.733         1.364      0.749
# 2020-10-01       0.358      1.063         2.675         1.330      0.724
# 2020-09-01       0.379      0.900         2.491         1.333      0.597
# 2020-08-01       0.389      0.786         2.370           NaN      0.560
# 2020-07-01       0.357      0.636         2.346           NaN      0.476
# 2020-06-01       0.359      0.656         2.080           NaN      0.481
# 2020-05-01       0.363      0.625         2.323           NaN      0.488
# 2020-04-01         NaN        NaN           NaN           NaN        NaN
# 2020-03-01       0.344      0.682         2.271         1.060      0.540
# 2020-02-01       0.329      0.691         2.252         1.069      0.542
# 2020-01-01       0.312      0.649         2.233         1.103      0.523
# 2019-12-01       0.279      0.564         2.229         1.169      0.528
# 2019-11-01       0.280      0.590         2.281         1.092      0.564
# 2019-10-01       0.226      0.639         2.301         1.099      0.595
# 2019-09-01       0.276      0.630         2.326         1.106      0.611
# 2019-08-01       0.436      0.657         2.436         1.116      0.626
# 2019-07-01       0.455      0.730         2.428         1.114      0.664
# 2021-04-01     0.4681   0.95766       2.3080       0.9442   0.80352
# 2021-03-01     0.4555   0.97240       2.3436       0.9588   0.81594
# 2021-02-01     0.4504   0.98076       2.3638       0.9670   0.82503
# 2021-01-01     0.4829   0.98802       2.3812       0.9740   0.82899
# 2020-12-01     0.4424   1.03444       2.4930       1.0198   0.86796
# 2020-11-01     0.4106   1.04401       2.5162       1.0294   0.87606
# 2020-10-01     0.4093   1.06062       2.5226       1.0320   0.87822
# 2020-09-01     0.4103   0.88605       2.5288       1.0346   0.71271
# 2020-08-01     0.4151   0.79618       2.5246       1.0328   0.66321
# 2020-07-01     0.3454   0.60269       2.2690          NaN   0.51426
# 2020-06-01     0.3897   0.66440       2.2758          NaN   0.62874
# 2020-05-01     0.3936   0.67100       2.5536          NaN   0.63504
# 2020-04-01        NaN       NaN          NaN          NaN       NaN
# 2020-03-01     0.3810   0.63415       2.6814       0.8532   0.60012
# 2020-02-01     0.3840   0.63943       2.7036       0.8602   0.60507
# 2020-01-01     0.3854   0.64207       2.7146       0.8638   0.60759
# 2019-12-01     0.2792   0.65109       2.7532       0.8760   0.61614
# 2019-11-01     0.3079   0.65307       2.7610       0.8786   0.61794
# 2019-10-01     0.3523   0.65736       2.7796       0.8844   0.62208
# 2019-09-01     0.3715   0.82511       2.7912       0.8880   0.78084
# 2019-08-01     0.4244   0.87989       2.7902       0.8878   0.83268
# 2019-07-01        NaN       NaN          NaN          NaN       NaN
# 2019-06-01        NaN       NaN          NaN          NaN       NaN
# 2019-05-01        NaN       NaN          NaN          NaN       NaN
# 2019-04-01        NaN       NaN          NaN          NaN       NaN
# 2019-03-01        NaN       NaN          NaN          NaN       NaN
# 2019-02-01        NaN       NaN          NaN          NaN       NaN
# 2019-01-01        NaN       NaN          NaN          NaN       NaN

# %%
data00.index
# Out:
# Index(['08/01/2023', '07/01/2023', '06/01/2023', '05/01/2023', '04/01/2023',
#        '03/01/2023', '02/01/2023', '01/01/2023', '12/01/2022', '11/01/2022',
#        '10/01/2022', '09/01/2022', '08/01/2022', '07/01/2022', '06/01/2022',
#        '05/01/2022', '04/01/2022', '03/01/2022', '02/01/2022', '01/01/2022',
#        '12/01/2021', '11/01/2021', '10/01/2021', '09/01/2021', '08/01/2021',
#        '07/01/2021', '06/01/2021', '05/01/2021', '04/01/2021', '03/01/2021',
#        '02/01/2021', '01/01/2021', '12/01/2020', '11/01/2020', '10/01/2020',
#        '09/01/2020', '08/01/2020', '07/01/2020', '06/01/2020', '05/01/2020',
#        '04/01/2020', '03/01/2020', '02/01/2020', '01/01/2020', '12/01/2019',
#        '11/01/2019', '10/01/2019', '09/01/2019', '08/01/2019', '07/01/2019',
#        '06/01/2019', '05/01/2019', '04/01/2019', '03/01/2019', '02/01/2019',
#        '01/01/2019'],
#       dtype='object', name='Date')

# %%
# number of empty rows of data
(data0.index.isnull()).nonzero()[0].shape
# Out:
# (156,)

# %% [markdown]
# * currently value error [ s needs to be increasing]
# * rows were empty
# * some of the dates are missing, for the range or am I reading empty cells?
