# %%
# %pylab inline
plt.style.use("default")
import os, sys
import scipy
import pandas as pd
import helpers as h
from glob import glob
from scipy.io import loadmat
from pynwb import NWBHDF5IO as nio 
from scipy.stats import skew, kurtosis

plt.rcParams['figure.figsize'] = (15, 10)
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
data_root = "/Users/duuta/ppp/data/sub-KS014/"
data_files = glob(f"{data_root}*.nwb")

# %%
rdata = nio(data_files[0], 'r', load_namespaces=True)
# Out:
# /Users/duuta/ppp/venv/lib/python3.9/site-packages/hdmf/spec/namespace.py:531: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.7.0 because version 1.5.1 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /Users/duuta/ppp/venv/lib/python3.9/site-packages/hdmf/spec/namespace.py:531: UserWarning: Ignoring cached namespace 'core' version 2.6.0-alpha because version 2.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /Users/duuta/ppp/venv/lib/python3.9/site-packages/hdmf/spec/namespace.py:531: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.4.0 because version 0.2.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."

# %%
adata = rdata.read()

# %%
adata
# Out:
# root pynwb.file.NWBFile at 0x6348538592
# Fields:
#   experiment_description: IBL aims to understand the neural basis of decision-making in the mouse by gathering a whole-brain activity map composed of electrophysiological recordings pooled from multiple laboratories. We have systematically recorded from nearly all major brain areas with Neuropixels probes, using a grid system for unbiased sampling and replicating each recording site in at least two laboratories. These data have been used to construct a brain-wide map of activity at single-spike cellular resolution during a decision-making task. In addition to the map, this data set contains other information gathered during the task: sensory stimuli presented to the mouse; mouse decisions and response times; and mouse pose information from video recordings and DeepLabCut analysis.
#
#   file_create_date: [datetime.datetime(2023, 7, 30, 20, 27, 38, 683333, tzinfo=tzutc())]
#   identifier: bec0976e-e598-4be1-af51-e72a7a0d0801
# ...

# %%
s0= adata.processing['behavior']['BodyCameraMotionEnergy'].data[:]

# %%
s_ = s0[: 80000]

# %%
imshow(s_.reshape(200, 400))

# %%
87286/3
# Out:
# 29095.333333333332

# %%
32766/295501
# Out:
# 0.1108828734928139

# %%
x
